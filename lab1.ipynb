# %%
name = input("Як вас звати? ")

print(f"Hello, {name}!")
# Out:
# Hello, Sehii!

# %%
import numpy as np  


random_array = np.random.rand(10)


average_value = np.mean(random_array)


print("Згенерований масив:")
print(random_array)
print("\nСереднє значення масиву:", average_value)
# Out:
# Згенерований масив:
# [0.11323328 0.31503767 0.58015678 0.14640286 0.81361967 0.30048932
#  0.5460073  0.73530795 0.18109819 0.59545973]
#
# Середнє значення масиву: 0.4326812753229972

# %% [markdown]
# # Лабораторна робота №1
# ## Призначення Jupyter Notebook
# Jupyter Notebook — це інструмент для інтерактивного програмування.
# Він дозволяє поєднувати в одному документі:
# - Код (наприклад, Python)
# - Текстові пояснення (Markdown)
# - Візуалізацію даних (графіки)
